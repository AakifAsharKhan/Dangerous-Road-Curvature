# %%
# Used for plotting of the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_json('json_file.json')
df
# Out:
#     Road segment Start latitude and longitude  End latitude and longitude  \
# 0              0   [13.35353198, 74.79086125]  [13.35315319, 74.78994927]
# 1              1   [13.35315319, 74.78994927]  [13.35276799, 74.78903342]
# 2              2   [13.35276799, 74.78903342]  [13.35244309, 74.78815689]
# 3              3   [13.35244309, 74.78815689]   [13.35241021, 74.7872268]
# 4              4    [13.35241021, 74.7872268]  [13.35186183, 74.78639458]
# 5              5   [13.35186183, 74.78639458]  [13.35104735, 74.78587091]
# 6              6   [13.35104735, 74.78587091]   [13.3501035, 74.78579988]
# 7              7    [13.3501035, 74.78579988]  [13.34919677, 74.78576729]
# 8              8   [13.34919677, 74.78576729]  [13.34841285, 74.78520569]
# 9              9   [13.34841285, 74.78520569]  [13.34770977, 74.78460668]
# 10            10   [13.34770977, 74.78460668]  [13.34843908, 74.78520427]
# 11            11   [13.34843908, 74.78520427]  [13.34920433, 74.78573687]
# ...

# %%
df.loc[5]['X_Acceleration']
# Out:
# [0.9592285156,
#  0.9104003906,
#  0.8776855469,
#  0.8214111328,
#  0.8247070312,
#  0.8493652344,
#  0.8481445312,
#  0.8278808594,
#  0.8221435547,
#  0.8621826172,
#  0.8947753906,
#  0.9219970703,
#  0.9284667969,
#  0.9598388672,
#  0.9320068359,
#  0.8984375,
#  0.9251708984,
#  0.9606933594,
#  0.9407958984,
#  0.9166259766,
#  0.9265136719,
#  0.9410400391,
#  0.9304199219,
#  0.8944091797,
#  0.9062500000000001,
#  1.0751953125,
#  1.0192871094,
#  0.9417724609,
#  0.8688964844,
#  0.8386230469,
#  0.8314208984,
#  0.8031005859,
#  0.8111572266,
#  0.8256835938,
#  0.8245849609,
#  0.8720703125,
#  0.9423828125,
#  1.0024414062,
#  1.0395507812,
#  1.1044921875,
#  1.1212158203,
#  1.0910644531,
#  1.0661621094,
#  1.0416259766,
#  0.9759521484,
#  0.8680419922,
#  0.7895507812,
#  0.7093505859,
#  0.7227783203,
#  0.751953125,
#  0.8527832031,
#  0.8670654297,
#  0.8862304688,
#  0.9376220703,
#  1,
#  1.0556640625,
#  1.0747070312,
#  1.0900878906,
#  1.1037597656,
# ...

# %%
plt.plot(df.loc[5]['Time'], df.loc[5]['Magnitude_Gyroscope'])
plt.xlabel('Time')
plt.ylabel('Gyroscope')
plt.show()

# %%
plt.plot(df.loc[5]['Time'], df.loc[5]['Magnitude_Accelerometer'])
plt.xlabel('Time')
plt.ylabel('Accelerometer')
plt.show()

# %%
plt.plot(df.loc[5]['Time'], df.loc[5]['X_Acceleration'])
plt.xlabel('Time')
plt.ylabel('X - Acceleration')
plt.show()

# %%
plt.plot(df.loc[5]['Time'], df.loc[5]['Y_Acceleration'])
plt.xlabel('Time')
plt.ylabel('Y - Acceleration')
plt.show()

# %%
plt.plot(df.loc[5]['Time'], df.loc[5]['Z_Acceleration'])
plt.xlabel('Time')
plt.ylabel('Z - Acceleration')
plt.show()
