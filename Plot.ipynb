# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_json('json_file.json')
df
# Out:
#     Road segment Start latitude and longitude  End latitude and longitude  \
# 0              0   [13.35353198, 74.79086125]  [13.35315319, 74.78994927]
# 1              1   [13.35315319, 74.78994927]  [13.35276799, 74.78903342]
# 2              2   [13.35276799, 74.78903342]  [13.35244309, 74.78815689]
# 3              3   [13.35244309, 74.78815689]   [13.35241021, 74.7872268]
# 4              4    [13.35241021, 74.7872268]  [13.35186183, 74.78639458]
# 5              5   [13.35186183, 74.78639458]  [13.35104735, 74.78587091]
# 6              6   [13.35104735, 74.78587091]   [13.3501035, 74.78579988]
# 7              7    [13.3501035, 74.78579988]  [13.34919677, 74.78576729]
# 8              8   [13.34919677, 74.78576729]  [13.34841285, 74.78520569]
# 9              9   [13.34841285, 74.78520569]  [13.34770977, 74.78460668]
# 10            10   [13.34770977, 74.78460668]  [13.34843908, 74.78520427]
# 11            11   [13.34843908, 74.78520427]  [13.34920433, 74.78573687]
# ...

# %%
df.loc[0]['X_Acceleration']
# Out:
# [0.9896240234,
#  0.9562988281,
#  0.9700927734,
#  0.9310302734,
#  0.8465576172,
#  0.9249267578,
#  0.9580078125,
#  0.9829101562,
#  1.0102539062,
#  1.0200195312,
#  0.9508056641,
#  0.8745117188,
#  0.8784179688,
#  0.9274902344,
#  0.9923095703,
#  1.0147705078,
#  0.9945068359,
#  1.0942382812,
#  1.1180419922,
#  1.0838623047,
#  1.0252685547,
#  0.9616699219,
#  0.8916015625,
#  0.7994384766,
#  0.7376708984,
#  0.7653808594,
#  0.8743896484,
#  0.9665527344,
#  0.8485107422,
#  0.8068847656,
#  0.7559814453,
#  0.7487792969,
#  0.7567138672,
#  0.7700195312,
#  0.7432861328,
#  0.7292480469,
#  0.7429199219,
#  0.7883300781,
#  0.8713378906,
#  0.9177246094,
#  0.9349365234,
#  0.9294433594,
#  0.8978271484,
#  0.8630371094,
#  0.8649902344,
#  0.8839111328,
#  0.8901367188,
#  0.8908691406,
#  0.9063720703,
#  0.9116210938,
#  0.9083251953,
#  0.9045410156,
#  0.9243164062,
#  0.9458007812,
#  0.9373779297,
#  0.9364013672,
#  0.9395751953,
#  0.9139404297,
# ...

# %%
plt.plot(df.loc[3]['Time'], df.loc[3]['Magnitude_Gyroscope'])
plt.xlabel('Time')
plt.ylabel('Gyroscope')
plt.show()

# %%
plt.plot(df.loc[3]['Time'], df.loc[3]['Magnitude_Accelerometer'])
plt.xlabel('Time')
plt.ylabel('Accelerometer')
plt.show()

# %%
plt.plot(df.loc[3]['Time'], df.loc[3]['X_Acceleration'])
plt.xlabel('Time')
plt.ylabel('X - Acceleration')
plt.show()

# %%
plt.plot(df.loc[3]['Time'], df.loc[3]['Y_Acceleration'])
plt.xlabel('Time')
plt.ylabel('Y - Acceleration')
plt.show()

# %%
plt.plot(df.loc[3]['Time'], df.loc[3]['Z_Acceleration'])
plt.xlabel('Time')
plt.ylabel('Z - Acceleration')
plt.show()
